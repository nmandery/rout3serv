# %% [markdown]
# This notebook renders a few example images and videos.
#
# Dependencies:
#
# * OSM - based graph of germany at `h3_resolution`
# * Running `route3_road` instance using that graph.
# * `ffmpeg`

# %%
import os.path
from pathlib import Path

notebookdir = Path(os.path.dirname(os.path.realpath("__file__")))

# additional libraries to the dev-dependencies of route3_road_client
# %pip install rasterio==1.2.10 matplotlib==3.5.1 earthpy==0.9.4 h3ronpy

import os
import subprocess
import numpy as np
import matplotlib.pyplot as plt
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep
import rasterio as rio
import geopandas as gpd
from rasterio.windows import transform
from rasterio.plot import plotting_extent
from h3ronpy.raster import raster_to_dataframe, nearest_h3_resolution
from h3ronpy.util import dataframe_to_geodataframe
import h3.api.numpy_int as h3

#bounds = (8.0, 48.2, 8.3, 48.4)
bounds = (8.0, 48.2, 8.4, 48.4)
h3_resolution = 10

# %%
#https://earthpy.readthedocs.io/en/latest/gallery_vignettes/plot_dem_hillshade.html
#with rio.open(os.path.expanduser("~/tmp/Copernicus_DSM_COG_10_N48_00_E008_00_DEM.tif")) as src:  

def fetch_elevation():
    with rio.Env(AWS_NO_SIGN_REQUEST="YES") as env:
        with rio.open("s3://copernicus-dem-30m/Copernicus_DSM_COG_10_N48_00_E008_00_DEM/Copernicus_DSM_COG_10_N48_00_E008_00_DEM.tif") as src:
            window = src.window(*bounds)
            window_transform = transform(window, src.transform)
            elevation = src.read(1, window=window)
            # Set masked values to np.nan
            elevation[elevation < 0] = np.nan
            
            pe = plotting_extent(elevation, transform=window_transform)
            return pe, elevation

def fetch_population():
    with rio.Env(AWS_NO_SIGN_REQUEST="YES") as env:
        with rio.open("s3://dataforgood-fb-data/hrsl-cogs/hrsl_general/hrsl_general-latest.vrt") as src:
            window = src.window(*bounds)
            window_transform = transform(window, src.transform)
            population_band = src.read(1, window=window)
            axis_order = "yx"
            
            conversion_h3_res = nearest_h3_resolution(population_band.shape, window_transform, axis_order=axis_order)
            
            population_band[np.isnan(population_band)] = 0
            
            df = raster_to_dataframe(population_band, window_transform, conversion_h3_res,
                                                nodata_value=0,
                                                compacted=False, axis_order=axis_order)
            df.rename(columns = {'value':'num_people'}, inplace = True)
            if h3_resolution > conversion_h3_res:
                raise ValueError(f"only h3 resolutions up to {conversion_h3_res}")
            elif h3_resolution < conversion_h3_res:
                # scale down
                df["h3index"] = df["h3index"].apply(lambda i: h3.h3_to_parent(i, h3_resolution))
                return df.groupby(by=["h3index"]).sum().reset_index()
            else: 
                return df

# %%
# Create and plot the hillshade with earthpy
hillshade_plotting_extent, elevation_arr = fetch_elevation()
hillshade = es.hillshade(elevation_arr, azimuth=270)
population = dataframe_to_geodataframe(fetch_population())

# %%
# print(hillshade_plotting_extent, bounds)

fig, ax = plt.subplots(figsize=(24, 24))

population.plot("num_people",
                ax=ax, 
                zorder=10, 
                alpha=0.9, 
                cmap="viridis", 
                edgecolor="black", 
                linewidth=0.3,
                #legend=True,
)

p_hillshade = ep.plot_bands(
    hillshade,
    ax=ax,
    cbar=False,
    alpha=0.3,
    extent=hillshade_plotting_extent,
    #title="Hillshade made from DTM",
)

plt.show()

# %%
import route3_road_client as rrc
import pyarrow as pa
from shapely.geometry import Polygon

def table_to_geodataframe(table: pa.Table, column_name: str = "h3index") -> gpd.GeoDataFrame:
    df = table.to_pandas()
    return gpd.GeoDataFrame(df,
                            geometry=[Polygon(h3.h3_to_geo_boundary(h, geo_json=True)) for h in
                                      np.nditer(df[column_name].to_numpy())],
                            crs=4326)


server = rrc.Server(hostport="127.0.0.1:7088")
graph_handle = rrc.build_graph_handle("germany", 10)

# %%
def calc_upto_some_threshold(gh, num_secs):
    origins = [   
        # h3.geo_to_h3(48.28713017627725, 8.111112713813782, gh.h3_resolution), # Fischerbach
        h3.geo_to_h3(48.291916615643935, 8.218567371368408, gh.h3_resolution) # Wolfach
    ]
    
    request = rrc.build_h3_within_threshold_request(
        gh,
        origins,
        travel_duration_secs_threshold=int(num_secs)
    )
    return server.h3_cells_within_threshold(request).table

from mpl_toolkits.axes_grid1 import make_axes_locatable
import tempfile

def within_threshold_render_frames(max_secs, step_secs):
    outdir = Path(tempfile.gettempdir()) / "vframes"
    if outdir.exists():
        import shutil
        shutil.rmtree(outdir)
    os.mkdir(outdir)

    gdf = table_to_geodataframe(calc_upto_some_threshold(graph_handle, max_secs), column_name="h3index_cell_origin")

    for secs in range(step_secs, max_secs, step_secs):
        step_gdf = gdf[gdf["travel_duration_secs"] <= secs]
        fig, ax = plt.subplots(figsize=(14, 14))

        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="2%", pad=0.1)
        #cax.tick_params(labelsize=25)

        step_gdf.plot("travel_duration_secs",
                        ax=ax, 
                        zorder=10, 
                        alpha=0.9, 
                        cmap="viridis", 
                        edgecolor="black", 
                        linewidth=0.3,
                        legend=True,
                        vmin=0, 
                        vmax=max_secs,
                        cax=cax,
        )

        p_hillshade = ep.plot_bands(
            hillshade,
            ax=ax,
            cbar=False,
            alpha=0.3,
            extent=hillshade_plotting_extent,
            title="Travel durations in the H3-grid graph [seconds]",
        )
        frame_num = int(secs/step_secs)
        outpng = outdir / f'f_{frame_num:05}.png'
        print(f"rendering {outpng}")
        plt.savefig(outpng, pad_inches=0, bbox_inches='tight')
        plt.close(fig)
    return outdir

#plt.show()

outdir = within_threshold_render_frames(60*20, 60*2)
# http://blog.pkh.me/p/21-high-quality-gif-with-ffmpeg.html
gif_filters="scale=800:-1:flags=lanczos"
gif_palette = outdir / "palette.png"
subprocess.check_call(["ffmpeg", "-y", "-i", f"{str(outdir)}/f_%05d.png", 
                      '-vf', f"{gif_filters},palettegen", str(gif_palette)])
subprocess.check_call(["ffmpeg", "-y", "-framerate", "2", "-i", f"{str(outdir)}/f_%05d.png", "-i", str(gif_palette), 
                       "-lavfi", f"{gif_filters} [x]; [x][1:v] paletteuse", 
                       f'{str(notebookdir)}/within-threshold.gif'])


outdir = within_threshold_render_frames(60*20, 5)
subprocess.check_call(["ffmpeg", "-y", "-framerate", "15", "-i", f"{str(outdir)}/f_%05d.png", 
                       '-crf', '25',
                       '-b', '10M',
                       "-pix_fmt", "yuv420p",
                       "-c:v", "libx264", # to be supported in firefox
                       "-movflags", "+faststart", # browser-specific 
                       "-filter:v", "crop='floor(in_w/2)*2:floor(in_h/2)*2'", # yuv420p only supports even width and height
                       f'{str(notebookdir)}/within-threshold.mp4'])
# Out:
# rendering /tmp/vframes/f_00001.png
# rendering /tmp/vframes/f_00002.png
# rendering /tmp/vframes/f_00003.png
# rendering /tmp/vframes/f_00004.png
# rendering /tmp/vframes/f_00005.png
# rendering /tmp/vframes/f_00006.png
# rendering /tmp/vframes/f_00007.png
# rendering /tmp/vframes/f_00008.png
# rendering /tmp/vframes/f_00009.png
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/tmp/vframes/f_%05d.png':
#   Duration: 00:00:00.36, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 816x401 [SAR 2835:2835 DAR 816:401], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/tmp/vframes/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_1 @ 0x55600f26ba80] 255(+1) colors generated out of 56484 colors; ratio=0.004515
# [Parsed_palettegen_1 @ 0x55600f26ba80] Dupped color: FF000000
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.207x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/tmp/vframes/f_%05d.png':
#   Duration: 00:00:04.50, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 816x401 [SAR 2835:2835 DAR 816:401], 2 fps, 2 tbr, 2 tbn, 2 tbc
# Input #1, png_pipe, from '/tmp/vframes/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> scale
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# Output #0, gif, to '/home/nico/CLionProjects/route3/crates/route3_road/doc/within-threshold.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 800x393 [SAR 20043:20050 DAR 816:401], q=2-31, 200 kb/s, 2 fps, 100 tbn, 2 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=    9 fps=0.0 q=-0.0 Lsize=    2047kB time=00:00:04.01 bitrate=4181.5kbits/s speed=  19x
# video:2047kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000954%
# rendering /tmp/vframes/f_00001.png
# rendering /tmp/vframes/f_00002.png
# rendering /tmp/vframes/f_00003.png
# rendering /tmp/vframes/f_00004.png
# rendering /tmp/vframes/f_00005.png
# rendering /tmp/vframes/f_00006.png
# rendering /tmp/vframes/f_00007.png
# rendering /tmp/vframes/f_00008.png
# rendering /tmp/vframes/f_00009.png
# rendering /tmp/vframes/f_00010.png
# rendering /tmp/vframes/f_00011.png
# rendering /tmp/vframes/f_00012.png
# rendering /tmp/vframes/f_00013.png
# rendering /tmp/vframes/f_00014.png
# rendering /tmp/vframes/f_00015.png
# rendering /tmp/vframes/f_00016.png
# rendering /tmp/vframes/f_00017.png
# rendering /tmp/vframes/f_00018.png
# rendering /tmp/vframes/f_00019.png
# rendering /tmp/vframes/f_00020.png
# rendering /tmp/vframes/f_00021.png
# rendering /tmp/vframes/f_00022.png
# rendering /tmp/vframes/f_00023.png
# rendering /tmp/vframes/f_00024.png
# rendering /tmp/vframes/f_00025.png
# rendering /tmp/vframes/f_00026.png
# rendering /tmp/vframes/f_00027.png
# rendering /tmp/vframes/f_00028.png
# rendering /tmp/vframes/f_00029.png
# rendering /tmp/vframes/f_00030.png
# rendering /tmp/vframes/f_00031.png
# rendering /tmp/vframes/f_00032.png
# rendering /tmp/vframes/f_00033.png
# rendering /tmp/vframes/f_00034.png
# rendering /tmp/vframes/f_00035.png
# rendering /tmp/vframes/f_00036.png
# rendering /tmp/vframes/f_00037.png
# rendering /tmp/vframes/f_00038.png
# rendering /tmp/vframes/f_00039.png
# rendering /tmp/vframes/f_00040.png
# rendering /tmp/vframes/f_00041.png
# rendering /tmp/vframes/f_00042.png
# rendering /tmp/vframes/f_00043.png
# rendering /tmp/vframes/f_00044.png
# rendering /tmp/vframes/f_00045.png
# rendering /tmp/vframes/f_00046.png
# rendering /tmp/vframes/f_00047.png
# rendering /tmp/vframes/f_00048.png
# rendering /tmp/vframes/f_00049.png
# rendering /tmp/vframes/f_00050.png
# rendering /tmp/vframes/f_00051.png
# rendering /tmp/vframes/f_00052.png
# rendering /tmp/vframes/f_00053.png
# rendering /tmp/vframes/f_00054.png
# rendering /tmp/vframes/f_00055.png
# rendering /tmp/vframes/f_00056.png
# rendering /tmp/vframes/f_00057.png
# rendering /tmp/vframes/f_00058.png
# rendering /tmp/vframes/f_00059.png
# rendering /tmp/vframes/f_00060.png
# rendering /tmp/vframes/f_00061.png
# rendering /tmp/vframes/f_00062.png
# rendering /tmp/vframes/f_00063.png
# rendering /tmp/vframes/f_00064.png
# rendering /tmp/vframes/f_00065.png
# rendering /tmp/vframes/f_00066.png
# rendering /tmp/vframes/f_00067.png
# rendering /tmp/vframes/f_00068.png
# rendering /tmp/vframes/f_00069.png
# rendering /tmp/vframes/f_00070.png
# rendering /tmp/vframes/f_00071.png
# rendering /tmp/vframes/f_00072.png
# rendering /tmp/vframes/f_00073.png
# rendering /tmp/vframes/f_00074.png
# rendering /tmp/vframes/f_00075.png
# rendering /tmp/vframes/f_00076.png
# rendering /tmp/vframes/f_00077.png
# rendering /tmp/vframes/f_00078.png
# rendering /tmp/vframes/f_00079.png
# rendering /tmp/vframes/f_00080.png
# rendering /tmp/vframes/f_00081.png
# rendering /tmp/vframes/f_00082.png
# rendering /tmp/vframes/f_00083.png
# rendering /tmp/vframes/f_00084.png
# rendering /tmp/vframes/f_00085.png
# rendering /tmp/vframes/f_00086.png
# rendering /tmp/vframes/f_00087.png
# rendering /tmp/vframes/f_00088.png
# rendering /tmp/vframes/f_00089.png
# rendering /tmp/vframes/f_00090.png
# rendering /tmp/vframes/f_00091.png
# rendering /tmp/vframes/f_00092.png
# rendering /tmp/vframes/f_00093.png
# rendering /tmp/vframes/f_00094.png
# rendering /tmp/vframes/f_00095.png
# rendering /tmp/vframes/f_00096.png
# rendering /tmp/vframes/f_00097.png
# rendering /tmp/vframes/f_00098.png
# rendering /tmp/vframes/f_00099.png
# rendering /tmp/vframes/f_00100.png
# rendering /tmp/vframes/f_00101.png
# rendering /tmp/vframes/f_00102.png
# rendering /tmp/vframes/f_00103.png
# rendering /tmp/vframes/f_00104.png
# rendering /tmp/vframes/f_00105.png
# rendering /tmp/vframes/f_00106.png
# rendering /tmp/vframes/f_00107.png
# rendering /tmp/vframes/f_00108.png
# rendering /tmp/vframes/f_00109.png
# rendering /tmp/vframes/f_00110.png
# rendering /tmp/vframes/f_00111.png
# rendering /tmp/vframes/f_00112.png
# rendering /tmp/vframes/f_00113.png
# rendering /tmp/vframes/f_00114.png
# rendering /tmp/vframes/f_00115.png
# rendering /tmp/vframes/f_00116.png
# rendering /tmp/vframes/f_00117.png
# rendering /tmp/vframes/f_00118.png
# rendering /tmp/vframes/f_00119.png
# rendering /tmp/vframes/f_00120.png
# rendering /tmp/vframes/f_00121.png
# rendering /tmp/vframes/f_00122.png
# rendering /tmp/vframes/f_00123.png
# rendering /tmp/vframes/f_00124.png
# rendering /tmp/vframes/f_00125.png
# rendering /tmp/vframes/f_00126.png
# rendering /tmp/vframes/f_00127.png
# rendering /tmp/vframes/f_00128.png
# rendering /tmp/vframes/f_00129.png
# rendering /tmp/vframes/f_00130.png
# rendering /tmp/vframes/f_00131.png
# rendering /tmp/vframes/f_00132.png
# rendering /tmp/vframes/f_00133.png
# rendering /tmp/vframes/f_00134.png
# rendering /tmp/vframes/f_00135.png
# rendering /tmp/vframes/f_00136.png
# rendering /tmp/vframes/f_00137.png
# rendering /tmp/vframes/f_00138.png
# rendering /tmp/vframes/f_00139.png
# rendering /tmp/vframes/f_00140.png
# rendering /tmp/vframes/f_00141.png
# rendering /tmp/vframes/f_00142.png
# rendering /tmp/vframes/f_00143.png
# rendering /tmp/vframes/f_00144.png
# rendering /tmp/vframes/f_00145.png
# rendering /tmp/vframes/f_00146.png
# rendering /tmp/vframes/f_00147.png
# rendering /tmp/vframes/f_00148.png
# rendering /tmp/vframes/f_00149.png
# rendering /tmp/vframes/f_00150.png
# rendering /tmp/vframes/f_00151.png
# rendering /tmp/vframes/f_00152.png
# rendering /tmp/vframes/f_00153.png
# rendering /tmp/vframes/f_00154.png
# rendering /tmp/vframes/f_00155.png
# rendering /tmp/vframes/f_00156.png
# rendering /tmp/vframes/f_00157.png
# rendering /tmp/vframes/f_00158.png
# rendering /tmp/vframes/f_00159.png
# rendering /tmp/vframes/f_00160.png
# rendering /tmp/vframes/f_00161.png
# rendering /tmp/vframes/f_00162.png
# rendering /tmp/vframes/f_00163.png
# rendering /tmp/vframes/f_00164.png
# rendering /tmp/vframes/f_00165.png
# rendering /tmp/vframes/f_00166.png
# rendering /tmp/vframes/f_00167.png
# rendering /tmp/vframes/f_00168.png
# rendering /tmp/vframes/f_00169.png
# rendering /tmp/vframes/f_00170.png
# rendering /tmp/vframes/f_00171.png
# rendering /tmp/vframes/f_00172.png
# rendering /tmp/vframes/f_00173.png
# rendering /tmp/vframes/f_00174.png
# rendering /tmp/vframes/f_00175.png
# rendering /tmp/vframes/f_00176.png
# rendering /tmp/vframes/f_00177.png
# rendering /tmp/vframes/f_00178.png
# rendering /tmp/vframes/f_00179.png
# rendering /tmp/vframes/f_00180.png
# rendering /tmp/vframes/f_00181.png
# rendering /tmp/vframes/f_00182.png
# rendering /tmp/vframes/f_00183.png
# rendering /tmp/vframes/f_00184.png
# rendering /tmp/vframes/f_00185.png
# rendering /tmp/vframes/f_00186.png
# rendering /tmp/vframes/f_00187.png
# rendering /tmp/vframes/f_00188.png
# rendering /tmp/vframes/f_00189.png
# rendering /tmp/vframes/f_00190.png
# rendering /tmp/vframes/f_00191.png
# rendering /tmp/vframes/f_00192.png
# rendering /tmp/vframes/f_00193.png
# rendering /tmp/vframes/f_00194.png
# rendering /tmp/vframes/f_00195.png
# rendering /tmp/vframes/f_00196.png
# rendering /tmp/vframes/f_00197.png
# rendering /tmp/vframes/f_00198.png
# rendering /tmp/vframes/f_00199.png
# rendering /tmp/vframes/f_00200.png
# rendering /tmp/vframes/f_00201.png
# rendering /tmp/vframes/f_00202.png
# rendering /tmp/vframes/f_00203.png
# rendering /tmp/vframes/f_00204.png
# rendering /tmp/vframes/f_00205.png
# rendering /tmp/vframes/f_00206.png
# rendering /tmp/vframes/f_00207.png
# rendering /tmp/vframes/f_00208.png
# rendering /tmp/vframes/f_00209.png
# rendering /tmp/vframes/f_00210.png
# rendering /tmp/vframes/f_00211.png
# rendering /tmp/vframes/f_00212.png
# rendering /tmp/vframes/f_00213.png
# rendering /tmp/vframes/f_00214.png
# rendering /tmp/vframes/f_00215.png
# rendering /tmp/vframes/f_00216.png
# rendering /tmp/vframes/f_00217.png
# rendering /tmp/vframes/f_00218.png
# rendering /tmp/vframes/f_00219.png
# rendering /tmp/vframes/f_00220.png
# rendering /tmp/vframes/f_00221.png
# rendering /tmp/vframes/f_00222.png
# rendering /tmp/vframes/f_00223.png
# rendering /tmp/vframes/f_00224.png
# rendering /tmp/vframes/f_00225.png
# rendering /tmp/vframes/f_00226.png
# rendering /tmp/vframes/f_00227.png
# rendering /tmp/vframes/f_00228.png
# rendering /tmp/vframes/f_00229.png
# rendering /tmp/vframes/f_00230.png
# rendering /tmp/vframes/f_00231.png
# rendering /tmp/vframes/f_00232.png
# rendering /tmp/vframes/f_00233.png
# rendering /tmp/vframes/f_00234.png
# rendering /tmp/vframes/f_00235.png
# rendering /tmp/vframes/f_00236.png
# rendering /tmp/vframes/f_00237.png
# rendering /tmp/vframes/f_00238.png
# rendering /tmp/vframes/f_00239.png
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/tmp/vframes/f_%05d.png':
#   Duration: 00:00:15.93, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 816x401 [SAR 2835:2835 DAR 816:401], 15 fps, 15 tbr, 15 tbn, 15 tbc
# Please use -b:a or -b:v, -b is ambiguous
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56267c08a0c0] using SAR=1/1
# [libx264 @ 0x56267c08a0c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56267c08a0c0] profile High, level 2.2
# [libx264 @ 0x56267c08a0c0] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=25.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/nico/CLionProjects/route3/crates/route3_road/doc/within-threshold.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 816x400 [SAR 1:1 DAR 51:25], q=-1--1, 10000 kb/s, 15 fps, 15360 tbn, 15 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/10000000 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x56267c087980] Starting second pass: moving the moov atom to the beginning of the file
# frame=  239 fps=0.0 q=-1.0 Lsize=     238kB time=00:00:15.73 bitrate= 124.2kbits/s speed=27.1x
# video:236kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.052318%
# [libx264 @ 0x56267c08a0c0] frame I:1     Avg QP:19.91  size: 82335
# [libx264 @ 0x56267c08a0c0] frame P:191   Avg QP:21.65  size:   808
# [libx264 @ 0x56267c08a0c0] frame B:47    Avg QP:23.27  size:    92
# [libx264 @ 0x56267c08a0c0] consecutive B-frames: 67.4% 17.6%  5.0% 10.0%
# [libx264 @ 0x56267c08a0c0] mb I  I16..4:  5.0% 24.5% 70.4%
# [libx264 @ 0x56267c08a0c0] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4:  2.7%  0.2%  0.2%  0.0%  0.0%    skip:96.8%
# [libx264 @ 0x56267c08a0c0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.2%  0.1%  0.0%  direct: 0.1%  skip:98.5%  L0:47.9% L1:51.1% BI: 1.0%
# [libx264 @ 0x56267c08a0c0] 8x8 transform intra:24.6% inter:7.2%
# [libx264 @ 0x56267c08a0c0] coded y,uvDC,uvAC intra: 94.8% 3.8% 3.6% inter: 0.9% 1.8% 1.7%
# [libx264 @ 0x56267c08a0c0] i16 v,h,dc,p: 50%  2% 48%  0%
# [libx264 @ 0x56267c08a0c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11%  5% 12% 12% 12%  9% 10% 12% 17%
# [libx264 @ 0x56267c08a0c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 12% 10% 10% 11%  8% 12% 10% 12%
# [libx264 @ 0x56267c08a0c0] i8c dc,h,v,p: 96%  0%  4%  0%
# [libx264 @ 0x56267c08a0c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56267c08a0c0] ref P L0: 89.2%  4.5%  4.3%  2.0%
# [libx264 @ 0x56267c08a0c0] ref B L0: 94.5%  4.4%  1.1%
# [libx264 @ 0x56267c08a0c0] ref B L1: 99.5%  0.5%
# [libx264 @ 0x56267c08a0c0] kb/s:120.99
# 0
